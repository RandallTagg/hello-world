# %% [markdown]
# # Jupyter notebook on Samsung tablet

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ### My sketch
# <div>
# <img src='./HandNotesSketches/pendulumSketch.PNG',alt='Pendulum apparatus'>
# </div>

# %% [markdown]
# <div>
#     <img src='./HandNotesSketches/snowsample.JPG',width='200',height'300'>
# </div>

# %% [markdown]
# ![pendulumSketch.PNG](attachment:pendulumSketch.PNG)
